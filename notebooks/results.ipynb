# %% [markdown]
# w pliku .pkl jest słownik, którego kluczami są nazwy 3 zbiorów danych: iris, liver, heart.
#
# Na każdym z tych zbiorów były robione 3 rzeczy, najpierw GridSearchCV, potem raz 5-foldCV z logowaniem wyników i w końcu 50 razy 5-fold CV, z którego zapisana jest tylko średnia dokładność.
#
# Każda wartość w słowniku to DataFrame z pandas. Każdy DataFrame ma kolumny z wynikami z 5 modeli: r2svm, r2elm, elm+rbfm, eml+sig, svm.
#
# Opis *części* nazw pól:
#
# * Pola ogólne:
#   * n_dim           - wymiarowość danych
#   * n_class         - ilośc klas
#   * 50x5-fold_mean  - srednia accuracy z 50 5-foldów
#   * 50x5-fold_std   - odchylenie standardowe z jw.
#
# * Pola z informacji z GridSearchCV:
#   * grid_time        - czas wywołania metody .fit(X,Y) na obekcie GridSearchCV z sklearn
#   * fold_params      - lista wszystkich parametrów modelu w gridzie
#   * mean_fold_scores - średni wynkich dla danych parametrów (len(mean_fold_scores) == len(fold_params))
#   * std_fold_scores  - odchylenie standardowe dla danych parametrów (jw.)
#   * best_std         - odchylenie standardwo dla najlepszych parametrów
#
# * Pola z infomacji z pojedynczego 5-fold dla najlepszych parametrów:
#   * acc_fold - dokładność w danych foldzie
#   * cm       - confusion matrix w danym foldzie
#   * mean_acc - średnia dokładność z 5-foldów
#   * std      - odchylenie strandardowe z 5-foldów
#
# Grid paramters dla modeli:

# %%
import sys
sys.path.append("..")

# %%
from pandas import DataFrame

# %%
import cPickle
import os
import pandas as pd
import numpy as np
from misc.config import c

results_dir = c['RESULTS_DIR']
file_name = 'ilh.res'

pd.options.display.float_format = '{:,.4f}'.format

# %%
iris = pd.io.parsers.read_csv(os.path.join(results_dir, "iris_results.csv"))
liver = pd.io.parsers.read_csv(os.path.join(results_dir, "liver_results.csv"))
heart = pd.io.parsers.read_csv(os.path.join(results_dir, "heart_results.csv"))
results = {"iris":iris, "liver":liver, "heart":heart}

# %%
def disp(d) :
    """better dictionary display"""
    assert type(d) == dict 
    for k, v in d.iteritems():
        print str(k)+':'
        print v 
        print '\n\n' 
    
def get_datasets(results):
    return results.keys()

def get_models(results):
    return results.values()[0].columns.values.tolist()

def get_columns(results):
    return results.values()[0].index.values.tolist()
    
def get_results(results, column, model=None, data=None):
    if data is None:
        data = get_datasets(results)
    if model is None:
        model = get_models(results)
    return { d: results[d].loc[column, model] for d in data }

# %%
iris["r2svm"][3]
# Out:
# "{'C': 0.1353352832366127, 'use_prev': True, 'recurrent': True, 'depth': 5, 'beta': 0.2, 'scale': False, 'fit_c': None, 'seed': 666}"

# %%
iris
# Out:
#           Unnamed: 0                                            elm+rbf  \
# 0     50x5-fold_mean                                0.91893333333333316
# 1      50x5-fold_std                               0.035984194061034959
# 2           acc_fold  [ 0.96666667  0.96666667  0.86666667  0.866666...
# 3        best_params        {'h': 20, 'activation': 'rbf', 'seed': 666}
# 4         best_score                                0.95333333333333337
# 5           best_std       [0.037712361663282512, 0.018856180831641284]
# 6                 cm  [array([[14,  0,  0],\n       [ 0,  7,  0],\n ...
# 7        fold_params  [{'h': 20, 'activation': 'rbf', 'seed': 666}, ...
# 8          grid_time                                 0.4612739086151123
# 9           mean_acc                                0.93333333333333324
# 10  mean_fold_scores  [0.95333333333333337, 0.93999999999999995, 0.9...
# 11               std                               0.055777335102271695
# 12   std_fold_scores  [0.037712361663282512, 0.028284271247461874, 0...
# 13         test_time  [8.606910705566406e-05, 8.082389831542969e-05,...
# 14        train_time  [0.0015499591827392578, 0.0015058517456054688,...
#
#                                               elm+sig  \
# 0                                 0.96226666666666671
# 1                                0.010800000000000023
# 2   [ 0.96666667  1.          0.96666667  0.933333...
# 3     {'h': 20, 'activation': 'sigmoid', 'seed': 666}
# 4                                 0.96666666666666667
# 5       [0.0094280904158206419, 0.024944382578492966]
# 6   [array([[10,  0,  0],\n       [ 0, 10,  1],\n ...
# 7   [{'h': 20, 'activation': 'sigmoid', 'seed': 66...
# 8                                 0.47921085357666016
# 9                                 0.97333333333333338
# 10  [0.96666666666666667, 0.96666666666666667, 0.9...
# 11                               0.024944382578492939
# 12  [0.0094280904158206419, 0.024944382578492966, ...
# 13  [0.00010514259338378906, 5.2928924560546875e-0...
# 14  [0.0016350746154785156, 0.004127025604248047, ...
#
#                                                 r2elm  \
# 0                                 0.93546666666666667
# 1                               0.0089878930913881074
# 2   [ 0.9         0.93333333  0.93333333  1.      ...
# 3   {'use_prev': False, 'h': 20, 'recurrent': True...
# 4                                 0.96666666666666667
# 5   [0.018856180831641284, 0.018856180831641284, 0...
# 6   [array([[ 9,  0,  0],\n       [ 0,  8,  0],\n ...
# 7   [{'use_prev': True, 'h': 20, 'recurrent': True...
# 8                                   313.6897611618042
# 9                                 0.94666666666666666
# 10  [0.76000000000000001, 0.76000000000000001, 0.8...
# 11                               0.033993463423951889
# 12  [0.071180521680208719, 0.071180521680208719, 0...
# 13  [0.0029840469360351562, 0.00023293495178222656...
# 14  [0.026582956314086914, 0.02266383171081543, 0....
#
#                                                 r2svm  \
# 0                                 0.70693333333333341
# 1                                0.046360136132481571
# 2   [ 0.73333333  0.76666667  0.6         0.6     ...
# 3   {'C': 0.1353352832366127, 'use_prev': True, 'r...
# 4                                 0.97333333333333338
# 5   [0.0094280904158206419, 0.0094280904158206419,...
# 6   [array([[ 9,  0,  0],\n       [ 3,  0,  5],\n ...
# 7   [{'C': 0.1353352832366127, 'use_prev': True, '...
# 8                                   94.08024597167969
# 9                                 0.69333333333333336
# 10  [0.83333333333333337, 0.83333333333333337, 0.9...
# 11                               0.077172246018601523
# 12  [0.033993463423951896, 0.033993463423951896, 0...
# 13  [0.0011420249938964844, 0.0011129379272460938,...
# 14  [0.032817840576171875, 0.027628183364868164, 0...
#
#                                                   svm
# 0                                 0.96679999999999988
# 1                               0.0072406261239389303
# 2   [ 0.96666667  0.93333333  1.          1.      ...
# 3   {'kernel': 'rbf', 'C': 2.7182818284590451, 'co...
# 4                                 0.97333333333333338
# 5   [0.0094280904158206419, 0.0094280904158206419,...
# 6   [array([[11,  0,  0],\n       [ 0, 11,  1],\n ...
# 7   [{'kernel': 'rbf', 'C': 0.1353352832366127, 'c...
# 8                                  0.5978400707244873
# 9                                 0.97333333333333327
# 10  [0.37333333333333335, 0.37333333333333335, 0.3...
# 11                               0.024944382578492939
# 12  [0.13199326582148888, 0.13199326582148888, 0.1...
# 13  [9.894371032714844e-05, 7.987022399902344e-05,...
# 14  [0.0005390644073486328, 0.0004341602325439453,...

# %%
liver
# Out:
#           Unnamed: 0                                            elm+rbf  \
# 0     50x5-fold_mean                                0.60568115942028988
# 1      50x5-fold_std                               0.059895477116006034
# 2           acc_fold  [ 0.39130435  0.46376812  0.44927536  0.521739...
# 3        best_params        {'h': 60, 'activation': 'rbf', 'seed': 666}
# 4         best_score                                0.67826086956521736
# 5           best_std                             [0.080012601401984129]
# 6                 cm  [array([[24,  5],\n       [37,  3]]), array([[...
# 7        fold_params  [{'h': 20, 'activation': 'rbf', 'seed': 666}, ...
# 8          grid_time                                 1.2360808849334717
# 9           mean_acc                                0.47826086956521741
# 10  mean_fold_scores  [0.66956521739130437, 0.672463768115942, 0.469...
# 11               std                               0.060105627111094823
# 12   std_fold_scores  [0.03253615118933862, 0.071117937080494464, 0....
# 13         test_time  [0.0002307891845703125, 0.00022602081298828125...
# 14        train_time  [0.02710700035095215, 0.023949146270751953, 0....
#
#                                               elm+sig  \
# 0                                 0.70110144927536222
# 1                                0.014956521739130408
# 2   [ 0.69565217  0.7826087   0.71014493  0.666666...
# 3     {'h': 30, 'activation': 'sigmoid', 'seed': 666}
# 4                                  0.6985507246376812
# 5                              [0.036434217652105916]
# 6   [array([[21, 13],\n       [ 8, 27]]), array([[...
# 7   [{'h': 20, 'activation': 'sigmoid', 'seed': 66...
# 8                                  1.4083728790283203
# 9                                 0.71304347826086956
# 10  [0.67536231884057973, 0.6985507246376812, 0.69...
# 11                               0.038234510023979498
# 12  [0.010845383729779567, 0.036434217652105916, 0...
# 13  [0.0001239776611328125, 0.0001201629638671875,...
# 14  [0.025650978088378906, 0.024616003036499023, 0...
#
#                                                 r2elm  \
# 0                                  0.6035942028985507
# 1                                0.015647449635938136
# 2   [ 0.53623188  0.44927536  0.5942029   0.739130...
# 3   {'use_prev': True, 'h': 20, 'recurrent': False...
# 4                                 0.68695652173913047
# 5   [0.043187433118119817, 0.043187433118119817, 0...
# 6   [array([[13, 20],\n       [12, 24]]), array([[...
# 7   [{'use_prev': True, 'h': 20, 'recurrent': True...
# 8                                   747.0717887878418
# 9                                 0.59130434782608687
# 10  [0.57681159420289851, 0.57681159420289851, 0.6...
# 11                               0.097177128198493945
# 12  [0.060384541031883086, 0.060384541031883086, 0...
# 13  [0.0005259513854980469, 0.0004990100860595703,...
# 14  [0.05186200141906738, 0.05196690559387207, 0.0...
#
#                                                 r2svm  \
# 0                                 0.52597101449275352
# 1                                0.016388581124134573
# 2   [ 0.62318841  0.49275362  0.62318841  0.434782...
# 3   {'C': 0.1353352832366127, 'use_prev': True, 'r...
# 4                                 0.69565217391304346
# 5   [0.049699791882557208, 0.049699791882557208, 0...
# 6   [array([[20,  8],\n       [18, 23]]), array([[...
# 7   [{'C': 0.1353352832366127, 'use_prev': True, '...
# 8                                  347.92625403404236
# 9                                 0.52753623188405796
# 10  [0.58260869565217388, 0.58260869565217388, 0.6...
# 11                               0.080222333351293029
# 12  [0.0070999702689367528, 0.0070999702689367528,...
# 13  [0.0010089874267578125, 0.0008261203765869141,...
# 14  [0.025933027267456055, 0.03597307205200195, 0....
#
#                                                   svm
# 0                                  0.7152463768115942
# 1                                0.011731935529960231
# 2   [ 0.72463768  0.75362319  0.72463768  0.681159...
# 3   {'kernel': 'rbf', 'C': 20.085536923187668, 'co...
# 4                                 0.73333333333333328
# 5                              [0.047273931682029265]
# 6   [array([[18,  8],\n       [11, 32]]), array([[...
# 7   [{'kernel': 'rbf', 'C': 0.1353352832366127, 'c...
# 8                                  1.5084378719329834
# 9                                 0.73043478260869565
# 10  [0.46956521739130436, 0.46956521739130436, 0.4...
# 11                               0.029842406205759408
# 12  [0.073785055428161495, 0.073785055428161495, 0...
# 13  [0.0005040168762207031, 0.0006439685821533203,...
# 14  [0.00836491584777832, 0.009268999099731445, 0....

# %%
heart
# Out:
#           Unnamed: 0                                            elm+rbf  \
# 0     50x5-fold_mean                                0.57592592592592595
# 1      50x5-fold_std                                0.02693537457122475
# 2           acc_fold  [ 0.55555556  0.57407407  0.55555556  0.481481...
# 3        best_params        {'h': 20, 'activation': 'rbf', 'seed': 666}
# 4         best_score                                0.61111111111111116
# 5           best_std                             [0.077512776060949445]
# 6                 cm  [array([[28,  0],\n       [24,  2]]), array([[...
# 7        fold_params  [{'h': 20, 'activation': 'rbf', 'seed': 666}, ...
# 8          grid_time                                  1.070478916168213
# 9           mean_acc                                0.54444444444444451
# 10  mean_fold_scores  [0.61111111111111116, 0.58148148148148149, 0.5...
# 11               std                               0.032288140322523522
# 12   std_fold_scores  [0.077512776060949445, 0.026189140043946214, 0...
# 13         test_time  [0.00416111946105957, 0.00011897087097167969, ...
# 14        train_time  [0.0030510425567626953, 0.0028510093688964844,...
#
#                                               elm+sig  \
# 0                                 0.81651851851851864
# 1                                0.017501087561738016
# 2   [ 0.77777778  0.7962963   0.7962963   0.814814...
# 3     {'h': 30, 'activation': 'sigmoid', 'seed': 666}
# 4                                 0.82592592592592595
# 5                              [0.020951312035156943]
# 6   [array([[28,  3],\n       [ 9, 14]]), array([[...
# 7   [{'h': 20, 'activation': 'sigmoid', 'seed': 66...
# 8                                  1.1133229732513428
# 9                                 0.79259259259259252
# 10  [0.79629629629629628, 0.82592592592592595, 0.7...
# 11                               0.013857990321384947
# 12  [0.020951312035156943, 0.020951312035156943, 0...
# 13  [0.00012302398681640625, 0.0001189708709716796...
# 14  [0.009620904922485352, 0.01718616485595703, 0....
#
#                                                 r2elm  \
# 0                                 0.83659259259259255
# 1                               0.0087532866647244117
# 2   [ 0.85185185  0.81481481  0.75925926  0.925925...
# 3   {'use_prev': True, 'h': 20, 'recurrent': True,...
# 4                                 0.84444444444444444
# 5   [0.041573970964154897, 0.041573970964154897, 0...
# 6   [array([[26,  4],\n       [ 4, 20]]), array([[...
# 7   [{'use_prev': True, 'h': 20, 'recurrent': True...
# 8                                   663.2832307815552
# 9                                 0.83703703703703702
# 10  [0.81851851851851853, 0.81851851851851853, 0.8...
# 11                               0.054180514216028854
# 12  [0.05237828008789238, 0.05237828008789238, 0.0...
# 13  [0.0002148151397705078, 0.00014901161193847656...
# 14  [0.00905609130859375, 0.009217977523803711, 0....
#
#                                                 r2svm  \
# 0                                 0.83533333333333348
# 1                               0.0059356401859453779
# 2   [ 0.85185185  0.7962963   0.81481481  0.870370...
# 3   {'C': 0.1353352832366127, 'use_prev': True, 'r...
# 4                                 0.85925925925925928
# 5   [0.036664796061524695, 0.036664796061524695, 0...
# 6   [array([[28,  2],\n       [ 6, 18]]), array([[...
# 7   [{'C': 0.1353352832366127, 'use_prev': True, '...
# 8                                     740.86652302742
# 9                                 0.84444444444444433
# 10  [0.84444444444444444, 0.84444444444444444, 0.8...
# 11                               0.034346735168502604
# 12  [0.01571348402636772, 0.01571348402636772, 0.0...
# 13  [0.0027441978454589844, 0.001750946044921875, ...
# 14  [0.033715009689331055, 0.03741717338562012, 0....
#
#                                                   svm
# 0                                 0.83607407407407408
# 1                               0.0063206500681457318
# 2   [ 0.83333333  0.87037037  0.87037037  0.759259...
# 3   {'kernel': 'rbf', 'C': 54.598150033144236, 'co...
# 4                                  0.8481481481481481
# 5                              [0.027715980642769925]
# 6   [array([[28,  6],\n       [ 3, 17]]), array([[...
# 7   [{'kernel': 'rbf', 'C': 0.1353352832366127, 'c...
# 8                                   1.416222095489502
# 9                                 0.83703703703703702
# 10  [0.50370370370370365, 0.50370370370370365, 0.5...
# 11                               0.041242698983926067
# 12  [0.085746940020668336, 0.085746940020668336, 0...
# 13  [0.000247955322265625, 0.0002799034118652344, ...
# 14  [0.001683950424194336, 0.01611495018005371, 0....

# %%
print 'Experiment data sets: ', get_datasets(results)
print
print 'Experiment models: ', get_models(results)
print
print 'All logged things: ', get_columns(results)
print
print 'Display some things: '
disp(get_results(results, column=['std', 'mean_acc']))

# %%
liver['r2svm'][3]
