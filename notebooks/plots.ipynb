# %%
# %load_ext autoreload
# %autoreload 2

# import seaborn

import sys
import os
sys.path.append("..")

from sklearn import svm, datasets
from sklearn.grid_search import ParameterGrid, GridSearchCV
from sklearn.base import BaseEstimator, clone 
from sklearn.cross_validation import KFold
from sklearn.svm import SVC
import os
import math
import numpy as np
import sklearn.metrics
from multiprocessing import Pool
from functools import partial

import sklearn
from sklearn.preprocessing import MinMaxScaler, LabelBinarizer
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import KFold
from sklearn.preprocessing import MinMaxScaler

from data_api import *

from r2 import *
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def plot(model, X, Y, layers=2):
    X_tr = model._X_tr
    
    N = 200
    plot_size=(10, 40)
    x, y = np.linspace(X[:,0].min(), X[:,0].max(), N),  np.linspace(X[:,1].min(), X[:,1].max(), N)
    xx, yy = np.meshgrid(x, y)
    z = model.predict(np.hstack([np.c_[xx.ravel(), yy.ravel(), np.zeros(shape=(N*N,zeros_size))] for _ in range(repeat)]))

    
    fig = plt.figure(figsize=plot_size)
    ax1 = fig.add_subplot(layers+1,1,1)
    ax1.contourf(xx, yy, z.reshape(N,N), cmap=plt.cm.Paired, alpha=0.8) #levels=np.arange(-2,2,0.2),
    ax1.scatter(X[:,0], X[:,1], c=Y,  cmap=plt.cm.Paired, alpha=0.8)

    for i in reversed(range(layers)):
        ax2 = fig.add_subplot(layers+1,1,2+(i))

        if len(model.W) > i:
            ax2.plot([0, model.W[i][1,0] - model.W[i][0,0]], [0, model.W[i][1,1] -  model.W[i][0,1]], 'k-', lw=4, c='r')

        ax2.contourf(model._X_tr[-i-1][:,0].reshape(N,N), model._X_tr[-i-1][:,1].reshape(N,N), z.reshape(N,N), 
                     cmap=plt.cm.Paired, alpha=0.8) #levels=np.arange(-2,2,0.2), 
        ax2.scatter(X_tr[-i-1][:,0], X_tr[-i-1][:,1], c=Y)
    plt.show()
plot(model, X, Y, layers=model.depth)

# %%
repeat = 10
zeros_size = 40
fig = plt.figure(figsize=(10,10))
X_tr = normal_model._X_tr
for i in range(normal_model.depth-1):
    ax2 = fig.add_subplot(1,normal_model.depth,i+1)
    ax2.set_aspect(1)
    
    N = 200
    plot_size=(10, 10)
    x, y = np.linspace(X[:,0].min(), X[:,0].max(), N),  np.linspace(X[:,1].min(), X[:,1].max(), N)
    xx, yy = np.meshgrid(x, y)
    z = normal_model.predict(np.hstack([np.c_[xx.ravel(), yy.ravel(), np.zeros(shape=(N*N,zeros_size))] for _ in range(repeat)]))

    
    ax2.plot([0, normal_model.W[i][1,0] - model.W[i][0,0]], [0, model.W[i][1,1] -  model.W[i][0,1]], 'k-', lw=4, c='r')
    
    ax2.contourf(normal_model._X_tr[i][:,0].reshape(N,N), model._X_tr[i][:,1].reshape(N,N), z.reshape(N,N), 
                 cmap=plt.cm.Paired, alpha=0.8) #levels=np.arange(-2,2,0.2), 
    ax2.scatter(X_tr[i][:,0], X_tr[i][:,1], c=Y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-93e78bc610f8> in <module>()
#      11     x, y = np.linspace(X[:,0].min(), X[:,0].max(), N),  np.linspace(X[:,1].min(), X[:,1].max(), N)
#      12     xx, yy = np.meshgrid(x, y)
# ---> 13     z = normal_model.predict(np.hstack([np.c_[xx.ravel(), yy.ravel(), np.zeros(shape=(N*N,zeros_size))] for _ in range(repeat)]))
#      14
#      15
#
# /lhome/home/czarnecki/st/r2-learner/r2-learner/r2.pyc in predict(self, X, all_layers)
#     238         # Prepare data
#     239         if self.scale:
# --> 240             X = self.scalers_[0].transform(X)
#     241
#     242         _X = [X]
#
# /lhome/home/czarnecki/.local/lib/python2.7/site-packages/sklearn/preprocessing/data.pyc in transform(self, X)
#     219         """
#     220         X = check_arrays(X, sparse_format="dense", copy=self.copy)[0]
# --> 221         X *= self.scale_
#     222         X += self.min_
#     223         return X
#
# ValueError: operands could not be broadcast together with shapes (40000,420) (2,) (40000,420)

# %% [markdown]
# # My Code

# %%
spirals = fetch_synthetic_datasets().spiral
moon = fetch_synthetic_datasets().moon
factor = 100
depth = 3

# %%
def multiply_dim(data, factor=10):
    return np.hstack([data for _ in xrange(factor)])

# %%
print spirals.data.shape
print multiply_dim(spirals.data, factor).shape
# Out:
# (300, 2)
# (300, 200)

# %%
normal_model = R2SVMLearner(seed=138668, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')
multi_model = R2SVMLearner(seed=4724, use_linear_svc=True, depth=3, beta=2, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')

# %%
X = MinMaxScaler((-1,1)).fit_transform(spirals.data)
multi_X = multiply_dim(X, factor)
Y = spirals.target

# X = MinMaxScaler((-1,1)).fit_transform(moon.data)
# multi_X = multiply_dim(X)
# Y = moon.target

print X.shape
print multi_X.shape
# Out:
# (300, 2)
# (300, 200)

# %%
X.max()
# Out:
# 1.0

# %%
normal_model.fit(X, Y)
multi_model.fit(multi_X, Y)
# Out:
# R2SVMLearner(C=1, activation='sigmoid', beta=2, depth=3, fit_c=None,
#        fixed_prediction=False, recurrent=True, scale=True, seed=4724,
#        switched=False, use_linear_svc=None, use_prev=False)

# %%
N = 200
x, y = np.linspace(X[:,0].min(), X[:,0].max(), N),  np.linspace(X[:,1].min(), X[:,1].max(), N)
xx, yy = np.meshgrid(x, y)

# %%
grid = np.c_[xx.ravel(), yy.ravel()]
multi_grid = np.hstack([np.c_[xx.ravel(), yy.ravel()] for _ in xrange(factor)])

print grid.shape
print multi_grid.shape
# Out:
# (40000, 2)
# (40000, 200)

# %%
predictions = normal_model.predict(grid, all_layers=True)
multi_predictions = multi_model.predict(multi_grid, all_layers=True)

# %%
print normal_model._X_tr[0][:,0].max()
print normal_model._X_tr[0][:,1].max()
# Out:
# 1.0
# 1.0

# %%
fig = plt.figure(figsize=(20,40))

for i in xrange(depth):
    ax = fig.add_subplot(depth+1, 2, 2*i+1)
    ax.set_aspect(1)
    
    ax.contourf(grid[:,0].reshape(N,N), grid[:,1].reshape(N,N), 
               predictions[i].reshape(N,N), cmap=plt.cm.Paired, alpha=0.8)
    ax.scatter(X[:,0], X[:,1], c=Y)
    ax.axis('off')
    
    ax2 = fig.add_subplot(depth+1, 2, 2*i+2)
    ax2.set_aspect(1)
    
    ax2.contourf(grid[:,0].reshape(N,N), grid[:,1].reshape(N,N),
                multi_predictions[i].reshape(N,N), cmap=plt.cm.Paired, alpha=0.8)
    ax2.scatter(X[:,0], X[:,1], c=Y)
    ax2.axis('off')

# %%
# Note moon is randomized!!
moon = fetch_synthetic_datasets().moon

# %%
model = R2SVMLearner(seed=16591, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')

X = MinMaxScaler((-1,1)).fit_transform(moon.data)
Y = moon.target    
Y_pred = model.fit(X,Y).predict(X)
score = accuracy_score(Y, Y_pred)
print(score)

model.fit(X, Y)

N = 300
x, y = np.linspace(X[:,0].min(), X[:,0].max(), N),  np.linspace(X[:,1].min(), X[:,1].max(), N)
xx, yy = np.meshgrid(x, y)
grid = np.c_[xx.ravel(), yy.ravel()]
predictions = model.predict(grid, all_layers=True)

fig_moons = plt.figure(figsize=(20,40))
layer_1 = fig_moons.add_subplot(1, 2, 1)
layer_1.set_aspect(1)
    
layer_1.contourf(grid[:,0].reshape(N,N), grid[:,1].reshape(N,N), 
            predictions[0].reshape(N,N), cmap=plt.cm.Paired)
layer_1.scatter(X[:,0], X[:,1], c=Y)
layer_1.set_title("First Layer - Linear SVM")
layer_1.axis('off')

layer_3 = fig_moons.add_subplot(1, 2, 2)
layer_3.set_aspect(1)

layer_3.contourf(grid[:,0].reshape(N,N), grid[:,1].reshape(N,N), 
            predictions[2].reshape(N,N),  cmap=plt.cm.Paired)
layer_3.scatter(X[:,0], X[:,1], c=Y)
layer_3.plot([0, model.W[1][1,0] - model.W[1][0,0]], [0, model.W[1][1,1] -  model.W[1][0,1]], 'k-', lw=4, c='r')


# need V here

layer_3.set_title("Third Layer - Best Result")
layer_3.axis('off')
# Out:
# 0.954
# (-1.109702317499522,
#  1.1291911027948143,
#  -1.7019844877668366,
#  1.1305550791219612)

# %%
X = MinMaxScaler((-1,1)).fit_transform(moon.data)
Y = moon.target

i = 0;
m = 0
best_seed = 0
while True:
    mo = R2SVMLearner(seed=i, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')
    
    Y_pred = mo.fit(X,Y).predict(X)
    score = accuracy_score(Y, Y_pred)
    
    if score > m:
        m = score
        best_seed = i
    if abs(score - 1) < 0.01:
        m = score
        best_seed = i
        print "!!!!!!! found best score:", m, "with seed:", best_seed, i
        break
    
    if i % 1000 == 0:
        print "best score so far:", m, "with seed:", best_seed
    
    sys.stdout.flush()
    
    i += 1
# Out:
# best score so far: 0.883 with seed: 0
# best score so far: 0.919 with seed: 239
# best score so far: 0.919 with seed: 239
# best score so far: 0.919 with seed: 239
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.936 with seed: 3695
# best score so far: 0.951 with seed: 13387
# best score so far: 0.951 with seed: 13387
# best score so far: 0.951 with seed: 13387
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.954 with seed: 16591
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# best score so far: 0.975 with seed: 38552
# !!!!!!! found best score: 0.996 with seed: 47666 47666

# %%
X = MinMaxScaler((-1,1)).fit_transform(moon.data)
Y = moon.target

model = R2SVMLearner(seed=239, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')
    
Y_pred = model.fit(X,Y).predict(X)
score = accuracy_score(Y, Y_pred)
score
# Out:
# 0.91900000000000004

# %%
X = MinMaxScaler((-1,1)).fit_transform(moon.data)
Y = moon.target
print sklearn.metrics.accuracy_score(R2SVMLearner(seed=3, beta=0.8).fit(X, Y).predict(X), Y)
# Out:
# 0.882

# %%
X = MinMaxScaler((-1,1)).fit_transform(spirals.data)
Y = spirals.target
print sklearn.metrics.accuracy_score(R2SVMLearner(seed=4, beta=0.8).fit(X, Y).predict(X), Y)
# Out:
# 0.513333333333

# %%
X = MinMaxScaler((-1,1)).fit_transform(spirals.data)
Y = spirals.target

i = 0;
m = 0
best_seed = 0
while True:
    mo = R2SVMLearner(seed=i, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid')
    
    Y_pred = mo.fit(X,Y).predict(X)
    score = accuracy_score(Y, Y_pred)
    
    if score > m:
        m = score
        best_seed = i
    if abs(score - 1) < 0.01:
        m = score
        best_seed = i
        print "!!!!!!! found best score:", m, "with seed:", best_seed, i
        break
    
    if i % 1000 == 0:
        print "best score so far:", m, "with seed:", best_seed
    i += 1
# Out:
# best score so far: 0.506666666667 with seed: 0
# best score so far:
#  0.653333333333 with seed: 66
# best score so far:
#  0.666666666667 with seed: 1236
# best score so far:
#  0.666666666667 with seed: 1236
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-48117cad2c23> in <module>()
#       9                  activation='sigmoid')
#      10
# ---> 11     Y_pred = mo.fit(X,Y).predict(X)
#      12     score = accuracy_score(Y, Y_pred)
#      13
#
# /lhome/home/czarnecki/st/r2-learner/r2-learner/r2.pyc in fit(self, X, Y, W)
#     231         # Fit
#     232         for i in xrange(self.depth):
# --> 233             X = self._feed_forward(X, i, Y)
#     234
#     235         return self
#
# /lhome/home/czarnecki/st/r2-learner/r2-learner/r2.pyc in _feed_forward(self, X, i, Y)
#      93         if not self._fitted:
#      94             if self.fit_c is None:
# ---> 95                 self.models_[i].fit(X, Y)
#      96             elif self.fit_c == 'random_cls' or self.fit_c == 'random_cls_centered':
#      97                 if i != self.depth - 1:
#
# /lhome/home/czarnecki/staszek_tmp/tradeshift/local/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /lhome/home/czarnecki/staszek_tmp/tradeshift/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# /lhome/home/czarnecki/staszek_tmp/tradeshift/local/lib/python2.7/site-packages/sklearn/utils/validation.pyc in _atleast2d_or_sparse(X, dtype, order, copy, sparse_class, convmethod, check_same_type, force_all_finite)
#     128 def _atleast2d_or_sparse(X, dtype, order, copy, sparse_class, convmethod,
#     129                          check_same_type, force_all_finite):
# --> 130     if sp.issparse(X):
#     131         if check_same_type(X) and X.dtype == dtype:
#     132             X = getattr(X, convmethod)(copy=copy)
#
# /lhome/home/czarnecki/staszek_tmp/tradeshift/local/lib/python2.7/site-packages/scipy/sparse/base.pyc in isspmatrix(x)
#     860
#     861 def isspmatrix(x):
# --> 862     return isinstance(x, spmatrix)
#     863
#     864 issparse = isspmatrix
#
# KeyboardInterrupt:

# %%
sklearn.metrics.accuracy_score(R2SVMLearner(seed=1236, use_linear_svc=True, depth=3, beta=0.9, fit_c=None, use_prev=False, scale=True, 
                 activation='sigmoid').fit(X,Y).predict(X), Y)
# Out:
# 0.66666666666666663
